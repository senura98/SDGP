# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('BreastCancerData (4).csv')

# %%
dataset
# Out:
#       Age        BMI  BreastFeeding  Marital Status  Alcohol  Smoking  \
# 0      48   8.543723              1               1        0        0
# 1      31  10.204207              1               1        0        0
# 2      31  13.807133              1               1        0        0
# 3      33  14.088867              1               1        1        0
# 4      49  14.494061              1               1        0        0
# ...   ...        ...            ...             ...      ...      ...
# 2383   29  42.647228              1               1        1        0
# 2384   29  43.258102              1               1        1        0
# 2385   51  44.171130              0               1        1        1
# 2386   41  57.760975              1               1        0        0
# 2387   35  69.500000              1               1        1        1
#
#       BreastCancerHistory  Age at firstPeriod  MenstrualCycle  Cancer Positive
# ...

# %%
X = dataset.iloc[:,:9].values

# %%
X
# Out:
# array([[48.        ,  8.5437225 ,  1.        , ...,  0.        ,
#         15.        ,  1.        ],
#        [31.        , 10.20420723,  1.        , ...,  0.        ,
#         12.        ,  1.        ],
#        [31.        , 13.80713296,  1.        , ...,  0.        ,
#         14.        ,  1.        ],
#        ...,
#        [51.        , 44.17113007,  0.        , ...,  1.        ,
#         14.        ,  0.        ],
#        [41.        , 57.76097459,  1.        , ...,  0.        ,
#         13.        ,  1.        ],
#        [35.        , 69.5       ,  1.        , ...,  1.        ,
#         15.        ,  1.        ]])

# %%
Y = dataset.iloc[:,9].values

# %%
Y
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.49883505, -0.31373932,  0.3505266 , ..., -0.17057206,
#         -0.65083898,  0.52849164],
#        [-1.39840675,  0.04582943,  0.3505266 , ..., -0.17057206,
#         -0.06886218,  0.52849164],
#        [ 0.01520592,  0.76143525,  0.3505266 , ..., -0.17057206,
#         -1.8147926 ,  0.52849164],
#        ...,
#        [-1.01287602, -0.52087625,  0.3505266 , ..., -0.17057206,
#         -0.06886218,  0.52849164],
#        [-1.14138627, -0.42179692, -2.8528505 , ..., -0.17057206,
#         -0.65083898,  0.52849164],
#        [ 0.91477763,  0.43737834,  0.3505266 , ..., -0.17057206,
#         -0.65083898,  0.52849164]])

# %%
X_test
# Out:
# array([[-1.14138627,  0.72313827,  0.3505266 , ..., -0.17057206,
#          1.09509144,  0.52849164],
#        [ 0.40073665,  0.09664523,  0.3505266 , ..., -0.17057206,
#         -1.23281579,  0.52849164],
#        [-0.75585554,  1.42050015,  0.3505266 , ..., -0.17057206,
#         -0.06886218,  0.52849164],
#        ...,
#        [-1.39840675,  0.8141352 ,  0.3505266 , ..., -0.17057206,
#          0.51311463,  0.52849164],
#        [-1.14138627, -0.23791359,  0.3505266 , ..., -0.17057206,
#         -0.65083898,  0.52849164],
#        [-1.39840675, -0.66948594,  0.3505266 , ..., -0.17057206,
#          0.51311463,  0.52849164]])

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=9))
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
classifier.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
classifier.fit(X_train,Y_train,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 1910/1910 [==============================] - 1s 337us/step - loss: 0.6710 - accuracy: 0.7628
# Epoch 2/100
# 1910/1910 [==============================] - 0s 125us/step - loss: 0.5247 - accuracy: 0.9387
# Epoch 3/100
# 1910/1910 [==============================] - 0s 116us/step - loss: 0.4250 - accuracy: 0.9455
# Epoch 4/100
# 1910/1910 [==============================] - 0s 102us/step - loss: 0.3804 - accuracy: 0.9476
# Epoch 5/100
# 1910/1910 [==============================] - 0s 102us/step - loss: 0.3466 - accuracy: 0.9482
# Epoch 6/100
# 1910/1910 [==============================] - 0s 105us/step - loss: 0.3191 - accuracy: 0.9508
# Epoch 7/100
# 1910/1910 [==============================] - 0s 105us/step - loss: 0.2958 - accuracy: 0.9524
# Epoch 8/100
# 1910/1910 [==============================] - 0s 104us/step - loss: 0.2770 - accuracy: 0.9513
# Epoch 9/100
# 1910/1910 [==============================] - 0s 105us/step - loss: 0.2615 - accuracy: 0.9503
# Epoch 10/100
# ...

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred
# Out:
# array([[0.01626008],
#        [0.89196604],
#        [0.973943  ],
#        [0.97354954],
#        [0.9772828 ],
#        [0.97727907],
#        [0.01626008],
#        [0.97507733],
#        [0.01626008],
#        [0.9772832 ],
#        [0.92677844],
#        [0.01626008],
#        [0.01626008],
#        [0.97692776],
#        [0.9653507 ],
#        [0.01626008],
#        [0.01626008],
#        [0.01626008],
#        [0.01626008],
#        [0.9468392 ],
#        [0.97576797],
#        [0.01626008],
#        [0.01944499],
#        [0.97720087],
#        [0.01626008],
#        [0.9769099 ],
#        [0.977188  ],
#        [0.01626008],
#        [0.9771968 ],
#        [0.01626008],
#        [0.97688216],
#        [0.9315346 ],
#        [0.01626008],
#        [0.9740251 ],
#        [0.01626008],
#        [0.01626008],
#        [0.01626008],
#        [0.08128979],
#        [0.01626008],
#        [0.9769577 ],
#        [0.977214  ],
#        [0.22804594],
#        [0.01626008],
# ...

# %%
y_pred=(y_pred>0.5)

# %%
y_pred
# Out:
# array([[False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(Y_test,y_pred)

# %%
cm
# Out:
# array([[271,  18],
#        [ 13, 176]], dtype=int64)

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       289
#            1       0.91      0.93      0.92       189
#
#     accuracy                           0.94       478
#    macro avg       0.93      0.93      0.93       478
# weighted avg       0.94      0.94      0.94       478

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.9351464435146444

# %%
import joblib as jb

# %%
jb.dump(classifier,'ANN_model_classifier.pkl')
# Out:
# ['ANN_model_classifier.pkl']

# %%
jb.dump(sc,'ANN_model_sc.pkl')
# Out:
# ['ANN_model_sc.pkl']

# %%
model1 = jb.load('ANN_model_classifier.pkl')

# %%
print(model1.predict(sc.transform([[23,25,1,1,0,0,0,12,1]])))
# Out:
# [[0.01626008]]

# %%
print(model1.predict(sc.transform([[23,25,1,1,0,0,0,12,1]]))[0][0]*100)
# Out:
# 1.6260083764791489

# %%
# Out:
# array([[1.6669692e-05]], dtype=float32)

# %%
# Out:
# array([[False]])

# %%
# Out:
# array([[False]])

# %%
# Out:
# 0

# %%
# Out:
# ['ANN_model.pkl']

# %%
# Out:
# array([[False]])

# %%
# Out:
# 0.1289745792746544

# %%
# Out:
# array([[ True]])

# %%
# Out:
# 99.80126619338989

# %%
# Out:
# 99.80126619338989

# %%
# Out:
# 0.0051355753
